# %% [markdown]
# # NPV Mini Project

# %% [markdown]
# A Company is having its offices across all locations of India. These locations are categorized with respect to zones.
#
# The company has decided to give medical expenditure benefits to their employees.
#
# The company has collected the medical expenditure of all the employees for the year 2019.
#
# The company also collected some other health and family related data of all employees like number of dependents, age, bmi, smoking and alcoholic habits.
#
#  Answer the following questions to provide insight into the collected dat.
#
# Dataset details **
#
# id: Employee id - unique
#
# age: age of primary beneficiary
#
# sex: Gender data - female, male
#
# bmi: Body mass index, providing an understanding of body, weights that are relatively high or low relative to height,
# objective index of body weight (kg / m ^ 2) using the ratio of height to weight, ideally 18.5 to 24.9
#
# dependent: Number of children other family members who are not earning and dependent on employee.
#
# alcohol: Alcohol consumption habit. Possible values - daily, weekend, party, no, rarely
#
# smoker: Smoking habit.
#
# zone: The office location zones. Possible values - east, west, south, north, northeast, southeast, southwest, northwest.
#
# expenditure: Individual medical expenditure by employees during year 2019
#
#  Read the dataset and do primary study of data. Perform following steps:
#  a. Reading some rows of dataset
#  b. Learn data types of all features
#  c. See the statistical properties of the data.

# %% [markdown]
# 1. How many employees above 50 age smoke, what is their average expenditure on health management?

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sb

# %%
df1 = pd.read_csv('emp_health.csv')
df1
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0     i10012   19  female  27.900          0    daily   yes  southwest
# 1     i10013   18    male  33.770          1  weekend    no      south
# 2     i10014   28    male  33.000          3   rarely    no      south
# 3     i10015   33    male  22.705          0    daily    no  northwest
# 4     i10016   32    male  28.880          0    party    no  northwest
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1333  i11345   50    male  30.970          3       no    no       west
# 1334  i11346   18  female  31.920          0    daily    no       east
# 1335  i11347   18  female  36.850          0  weekend    no  southeast
# 1336  i11348   21  female  25.800          0    party    no  southwest
# 1337  i11349   61  female  29.070          0       no   yes       west
#
#       expenditure
# 0     16884.92400
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# ...

# %%
df2 = df1[df1.smoke=='yes'].nlargest(50, ['age'])
print ("Average expenditure:", df2['expenditure'].mean())
df2
# Out:
# Average expenditure: 39651.642295
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 94    i10106   64  female  31.300          2    party   yes  southwest
# 328   i10340   64  female  33.800          1  weekend   yes  southwest
# 420   i10432   64    male  33.880          0  weekend   yes  southeast
# 664   i10676   64  female  22.990          0  weekend   yes       east
# 890   i10902   64  female  26.885          0    party   yes  northwest
# 1241  i11253   64    male  36.960          2       no   yes  southeast
# 1265  i11277   64    male  23.760          0  weekend   yes  southeast
# 109   i10121   63    male  35.090          0    daily   yes      south
# 175   i10187   63  female  37.700          0       no   yes  southwest
# 244   i10256   63  female  27.740          0       no   yes      north
# 251   i10263   63  female  32.200          2    party   yes  southwest
# 419   i10431   63  female  26.980          0    party   yes       west
# ...

# %% [markdown]
#  2. How many female employees did not consume alcohol daily. What is their proportion with respect to total female employees?

# %%
df3 = df1[(df1.sex=='female') & (df1.alcohol!='daily')&(df1.alcohol!='no')]
d16 = df3.sex.size
d16
# Out:
# 341

# %%
df4 = df1[(df1.sex=='female')]
d17 = df4.sex.size
d17
# Out:
# 662

# %%
df15 = d16 / d17
print ("Their proportion with respect to total female employees: ", df15)
# Out:
# Their proportion with respect to total female employees:  0.5151057401812689

# %% [markdown]
#  3. Display zone wise average expenditure of employees on health

# %%
zone_wise= df1.groupby(by='zone')['expenditure']
df_exp= zone_wise.sum('zone')
df_exp1 = pd.DataFrame(df_exp)
df_exp1
# Out:
#             expenditure
# zone
# east       3.608966e+06
# north      9.871808e+05
# northeast  1.013409e+06
# northwest  1.761997e+06
# south      1.236118e+06
# southeast  2.861684e+06
# southwest  3.191988e+06
# west       3.094482e+06

# %% [markdown]
# 4. Employees of which zone did maximum expenditure on health

# %%
df_exp1.groupby(by=['zone']).agg(['max']).head(1)
# Out:
#        expenditure
#                max
# zone
# east  3.608966e+06

# %%
df1.groupby(by=['zone']).agg(['max'])['expenditure']
# Out:
#                    max
# zone
# east       58571.07448
# north      48549.17835
# northeast  46255.11250
# northwest  55135.40209
# south      47055.53210
# southeast  63770.42801
# southwest  52590.82939
# west       60021.39897

# %% [markdown]
# 5. What is the minimum expenditure done by any employee in organization

# %%
df1.sort_values(by='expenditure', axis=0, ascending=True).min()
# Out:
# id                i10012
# age                   18
# sex               female
# bmi                15.96
# dependent              0
# alcohol            daily
# smoke                 no
# zone                east
# expenditure    1121.8739
# dtype: object

# %%
df_min = df1.groupby(by='expenditure').min()
df_min
# Out:
#                  id  age     sex     bmi  dependent  alcohol smoke       zone
# expenditure
# 1121.87390   i10952   18    male  23.210          0    party    no  southeast
# 1131.50660   i10820   18    male  30.140          0    daily    no       east
# 1135.94070   i11256   18    male  33.330          0   rarely    no  southeast
# 1136.39940   i10675   18    male  33.660          0    daily    no       east
# 1137.01100   i10034   18    male  34.100          0    daily    no      south
# ...             ...  ...     ...     ...        ...      ...   ...        ...
# 55135.40209  i10831   33  female  35.530          0    daily   yes  northwest
# 58571.07448  i10589   31  female  38.095          1    daily   yes       east
# 60021.39897  i11242   52    male  34.485          3  weekend   yes       west
# 62592.87309  i11312   45    male  30.360          0    party   yes  southeast
# 63770.42801  i10555   54  female  47.410          0    party   yes  southeast
#
# ...

# %% [markdown]
# 6. What is average expenditure of employees who have 2 or lesser dependents

# %%
df5 = df1[df1.dependent <2]
df5.groupby(by=['dependent']).agg(['mean']).mean()['expenditure']
# Out:
# mean    12548.573717
# dtype: float64

# %%
df5 = df1[df1.dependent <2]
df5.groupby(by=['dependent']).agg(['mean'])
# Out:
#                  age        bmi   expenditure
#                 mean       mean          mean
# dependent
# 0          38.444251  30.550296  12365.975602
# 1          39.453704  30.623148  12731.171832

# %%
df6 = pd.pivot_table(df5, aggfunc='mean',index='dependent', values=['expenditure']).mean()
df6
# Out:
# expenditure    12548.573717
# dtype: float64

# %% [markdown]
#  7. How many employees are below age of 20 years. What is their average BMI

# %%
df7 = df1[df1.age <20]
df7.groupby(by=['dependent']).agg(['mean'])
# Out:
#                  age        bmi   expenditure
#                 mean       mean          mean
# dependent
# 0          18.495050  30.567574   8557.034670
# 1          18.550000  28.446250   4078.493262
# 2          18.454545  27.662273  14198.497355
# 3          18.333333  28.536667  13514.674287
# 4          18.000000  31.350000   4561.188500
# 5          19.000000  28.600000   4687.797000

# %%
df7.groupby(by=['dependent']).agg(['mean']).mean()['bmi']
# Out:
# mean    29.193794
# dtype: float64

# %% [markdown]
# 8. Create a dataframe "non_smoker" for all non-smoker male employees

# %%
non_smoker = df1[(df1.smoke == 'no') & (df1.sex=='male') ]
non_smoker
# Out:
#           id  age   sex     bmi  dependent  alcohol smoke       zone  \
# 1     i10013   18  male  33.770          1  weekend    no      south
# 2     i10014   28  male  33.000          3   rarely    no      south
# 3     i10015   33  male  22.705          0    daily    no  northwest
# 4     i10016   32  male  28.880          0    party    no  northwest
# 8     i10020   37  male  29.830          2    party    no      north
# ...      ...  ...   ...     ...        ...      ...   ...        ...
# 1324  i11336   31  male  25.935          1    daily    no       west
# 1325  i11337   61  male  33.535          0    party    no       east
# 1327  i11339   51  male  30.030          1    daily    no  southeast
# 1329  i11341   52  male  38.600          2    party    no  southwest
# 1333  i11345   50  male  30.970          3       no    no       west
#
#       expenditure
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# 8      6406.41070
# ...           ...
# ...

# %% [markdown]
# 9. Create a dataframe "non_alcoholic" for all male employees who do not consume alcohol

# %%
non_alcoholic = df1[(df1.alcohol == 'no') & (df1.sex=='male') ]
non_alcoholic
# Out:
#           id  age   sex     bmi  dependent alcohol smoke       zone  \
# 18    i10030   56  male  40.300          0      no    no  southwest
# 24    i10036   37  male  28.025          2      no    no  northwest
# 28    i10040   23  male  17.385          1      no    no  northwest
# 37    i10049   26  male  20.800          0      no    no  southwest
# 38    i10050   35  male  36.670          1      no   yes      north
# ...      ...  ...   ...     ...        ...     ...   ...        ...
# 1291  i11303   19  male  34.900          0      no   yes  southwest
# 1301  i11313   62  male  30.875          3      no   yes       west
# 1310  i11322   42  male  26.315          1      no    no       west
# 1320  i11332   31  male  31.065          3      no    no       west
# 1333  i11345   50  male  30.970          3      no    no       west
#
#       expenditure
# 18    10602.38500
# 24     6203.90175
# 28     2775.19215
# 37     2302.30000
# 38    39774.27630
# ...           ...
# ...

# %% [markdown]
# 10. Create a dataframe called "non_smoking_alcoholic" with the men employees who do not smoke and consume alcohol. The dataframe should contain columns id, smoke, alcohol
#  (Hint:Use join and dataframes created in Q8 and Q9)

# %%
non_smoking_alocholic = pd.concat(objs = [non_smoker, non_alcoholic], axis = 0, join = 'inner')

# %%
non_smoking_alocholic
# Out:
#           id  age   sex     bmi  dependent  alcohol smoke       zone  \
# 1     i10013   18  male  33.770          1  weekend    no      south
# 2     i10014   28  male  33.000          3   rarely    no      south
# 3     i10015   33  male  22.705          0    daily    no  northwest
# 4     i10016   32  male  28.880          0    party    no  northwest
# 8     i10020   37  male  29.830          2    party    no      north
# ...      ...  ...   ...     ...        ...      ...   ...        ...
# 1291  i11303   19  male  34.900          0       no   yes  southwest
# 1301  i11313   62  male  30.875          3       no   yes       west
# 1310  i11322   42  male  26.315          1       no    no       west
# 1320  i11332   31  male  31.065          3       no    no       west
# 1333  i11345   50  male  30.970          3       no    no       west
#
#       expenditure
# 1      1725.55230
# 2      4449.46200
# 3     21984.47061
# 4      3866.85520
# 8      6406.41070
# ...           ...
# ...

# %% [markdown]
#  11.What is the count for each zone with respect to number of dependent

# %%
pd.crosstab(index=df1.zone, columns = df1.dependent)
# Out:
# dependent    0   1   2   3  4  5
# zone
# east       124  65  42  22  6  3
# north       26  20  10  12  1  1
# northeast   35   9  15  13  2  0
# northwest   70  28  30  13  4  0
# south       38  21  12  12  1  0
# southeast   81  57  38  15  2  5
# southwest  116  53  44  25  6  7
# west        84  71  49  45  3  2

# %% [markdown]
# 12. Classify the employees into 3 categories.
#
#  Category 1 : employees below 18.5 bmi - underweight
#
#  Category 2 : employees with bmi in the range of 18.5 to 24.9 - fit
#
#  Category 3 : employee with bmi over 24.9 - overweight
#
#  What is the average expenditure of employees in each category.
#
#  Display the bar chart for the same

# %%
def bmirank(v):
    if v<18.5:
        return 'underweight'
    elif (v > 18.5) & (v < 24.9):
        return 'fit'
    else:
        return 'overweight'

# %%
df1['bmi_scale'] = df1.bmi.map(bmirank)
df1
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0     i10012   19  female  27.900          0    daily   yes  southwest
# 1     i10013   18    male  33.770          1  weekend    no      south
# 2     i10014   28    male  33.000          3   rarely    no      south
# 3     i10015   33    male  22.705          0    daily    no  northwest
# 4     i10016   32    male  28.880          0    party    no  northwest
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1333  i11345   50    male  30.970          3       no    no       west
# 1334  i11346   18  female  31.920          0    daily    no       east
# 1335  i11347   18  female  36.850          0  weekend    no  southeast
# 1336  i11348   21  female  25.800          0    party    no  southwest
# 1337  i11349   61  female  29.070          0       no   yes       west
#
#       expenditure   bmi_scale
# 0     16884.92400  overweight
# 1      1725.55230  overweight
# ...

# %%
#the average expenditure of employees in each category.
df8 = df1.groupby(by=['bmi_scale']).agg(['mean'])['expenditure']
df8
# Out:
#                      mean
# bmi_scale
# fit          10404.900084
# overweight   13928.257120
# underweight   8852.200585

# %%
#Display the bar chart for the same

df8.plot(kind='bar')
plt.ylabel('expenditure mean')
plt.title('Bmi expenditure bar')
# Out:
# Text(0.5, 1.0, 'Bmi expenditure bar')

# %% [markdown]
# 13. Draw line plot of expenditure against age and BMI

# %%
df9 = df1.drop(columns = ['id', 'sex', 'dependent', 'alcohol','smoke', 'bmi_scale', 'zone']).sort_values(by='expenditure')
df9
# Out:
#       age     bmi  expenditure
# 940    18  23.210   1121.87390
# 808    18  30.140   1131.50660
# 1244   18  33.330   1135.94070
# 663    18  33.660   1136.39940
# 22     18  34.100   1137.01100
# ...   ...     ...          ...
# 819    33  35.530  55135.40209
# 577    31  38.095  58571.07448
# 1230   52  34.485  60021.39897
# 1300   45  30.360  62592.87309
# 543    54  47.410  63770.42801
#
# [1338 rows x 3 columns]

# %%
df9.sort_values(by='age').plot(kind='line', x='expenditure', y='age',marker="*",figsize=(20,10))
df9.sort_values(by='bmi').plot(kind='line', x='bmi', y='expenditure',marker=">",figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='bmi'>

# %% [markdown]
# 14. Draw a bar chart to show zone wise average expenditure

# %%
df_exp1.plot(kind='bar')
plt.ylabel('expenditure mean')
plt.title('zone expenditure bar')
# Out:
# Text(0.5, 1.0, 'zone expenditure bar')

# %% [markdown]
# 15. Draw a bar chart to show smoking and alcoholic habits against average expenditure

# %%
smo_alcoholic = df1[(df1.smoke == 'yes') & (df1.alcohol!='no') ]
smo_alcoholic
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0     i10012   19  female  27.900          0    daily   yes  southwest
# 11    i10023   62  female  26.290          0    daily   yes      south
# 14    i10026   27    male  42.130          0  weekend   yes      south
# 19    i10031   30    male  35.300          0    daily   yes  southwest
# 23    i10035   34  female  31.920          1    party   yes      north
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1308  i11320   25  female  30.200          0    party   yes  southwest
# 1313  i11325   19  female  34.700          2    daily   yes  southwest
# 1314  i11326   30  female  23.655          3    daily   yes       west
# 1321  i11333   62    male  26.695          0    daily   yes       east
# 1323  i11335   42  female  40.370          2   rarely   yes  southeast
#
#       expenditure   bmi_scale
# 0     16884.92400  overweight
# 11    27808.72510  overweight
# ...

# %%
df9 = smo_alcoholic.groupby(by=['alcohol','smoke']).agg(['mean'])['expenditure']
df9
# Out:
#                        mean
# alcohol smoke
# daily   yes    31160.402608
# party   yes    31487.938163
# rarely  yes    31881.367379
# weekend yes    33592.294629

# %%
df9.plot(kind='bar')
plt.ylabel('expenditure')
plt.title('Alco_smo expenditure bar')
# Out:
# Text(0.5, 1.0, 'Alco_smo expenditure bar')

# %% [markdown]
# 16. Draw pie chart for alcohol consumption habits

# %%
df10 = df1[df1.alcohol!='no']
df10
# Out:
#           id  age     sex     bmi  dependent  alcohol smoke       zone  \
# 0     i10012   19  female  27.900          0    daily   yes  southwest
# 1     i10013   18    male  33.770          1  weekend    no      south
# 2     i10014   28    male  33.000          3   rarely    no      south
# 3     i10015   33    male  22.705          0    daily    no  northwest
# 4     i10016   32    male  28.880          0    party    no  northwest
# ...      ...  ...     ...     ...        ...      ...   ...        ...
# 1331  i11343   23  female  33.400          0    daily    no  southwest
# 1332  i11344   52  female  44.700          3    party    no  southwest
# 1334  i11346   18  female  31.920          0    daily    no       east
# 1335  i11347   18  female  36.850          0  weekend    no  southeast
# 1336  i11348   21  female  25.800          0    party    no  southwest
#
#       expenditure   bmi_scale
# 0     16884.92400  overweight
# 1      1725.55230  overweight
# ...

# %%
vc = df10.alcohol.value_counts()
vc
# Out:
# daily      395
# weekend    347
# party      278
# rarely      59
# Name: alcohol, dtype: int64

# %%
plt.pie(x=vc.values, labels = vc.index, autopct = '%.2f')
plt.show()

# %% [markdown]
# 17. Draw scatterplot to see the relation between age and expenditure, keep smoking habit as hue

# %%
df11 = df1.drop(columns = ['id', 'sex', 'bmi', 'dependent', 'alcohol', 'bmi_scale', 'zone']).sort_values(by='expenditure')
df11
# Out:
#       age smoke  expenditure
# 940    18    no   1121.87390
# 808    18    no   1131.50660
# 1244   18    no   1135.94070
# 663    18    no   1136.39940
# 22     18    no   1137.01100
# ...   ...   ...          ...
# 819    33   yes  55135.40209
# 577    31   yes  58571.07448
# 1230   52   yes  60021.39897
# 1300   45   yes  62592.87309
# 543    54   yes  63770.42801
#
# [1338 rows x 3 columns]

# %%
df12 = df11.sort_values(by='age')
df12
# Out:
#      age smoke  expenditure
# 940   18    no   1121.87390
# 57    18   yes  34303.16720
# 911   18   yes  33732.68670
# 369   18    no   3481.86800
# 710   18    no   1727.54000
# ..   ...   ...          ...
# 420   64   yes  46889.26120
# 768   64    no  14319.03100
# 801   64    no  14313.84630
# 402   64    no  14692.66935
# 534   64    no  13831.11520
#
# [1338 rows x 3 columns]

# %%
sb.scatterplot(x='age', y='expenditure',hue='smoke', data=df12)
# Out:
# <AxesSubplot:xlabel='age', ylabel='expenditure'>

# %% [markdown]
# 18. Draw distribution plot of expenditure

# %%
df13 = df11.sort_values(by='expenditure')
df13
# Out:
#       age smoke  expenditure
# 940    18    no   1121.87390
# 808    18    no   1131.50660
# 1244   18    no   1135.94070
# 663    18    no   1136.39940
# 22     18    no   1137.01100
# ...   ...   ...          ...
# 819    33   yes  55135.40209
# 577    31   yes  58571.07448
# 1230   52   yes  60021.39897
# 1300   45   yes  62592.87309
# 543    54   yes  63770.42801
#
# [1338 rows x 3 columns]

# %%
sb.displot(df13['expenditure'])

# %% [markdown]
# 19. Display the pairplot

# %%
sb.pairplot(df1)

# %% [markdown]
#  20. Display heatmap for the data

# %%
df14 = df1.drop(columns = ['id', 'sex', 'zone', 'smoke', 'alcohol', 'bmi_scale'])
df14


sb.heatmap(df14)
# Out:
# <AxesSubplot:>
